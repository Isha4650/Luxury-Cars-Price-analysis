# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\VICTUS\\Desktop\\python\\cardatasetEda1.csv")
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(715)

# %%
df=df.drop_duplicates()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print("Before:", df.shape)
df.drop_duplicates(inplace=True)
print("After:",df.shape)
# Out:
# Before: (11199, 16)
# After: (11199, 16)
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_21240\2952931624.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df_cleaned = df.drop_duplicates()

# %%
df_cleaned = df_cleaned.dropna(subset=["Engine HP", "Engine Cylinders", "Number of Doors"])
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df_cleaned["Market Category"] = df_cleaned["Market Category"].fillna("Unknown") 
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.drop(['Market Category', 'Model',],axis=1,inplace=True)
df
# Out:
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_21240\324455207.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['Market Category', 'Model',],axis=1,inplace=True)
#           Make  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  2011     premium unleaded (required)      335.0
# 1          BMW  2011     premium unleaded (required)      300.0
# 2          BMW  2011     premium unleaded (required)      300.0
# 3          BMW  2011     premium unleaded (required)      230.0
# 4          BMW  2011     premium unleaded (required)      230.0
# ...        ...   ...                             ...        ...
# 11909    Acura  2012     premium unleaded (required)      300.0
# 11910    Acura  2012     premium unleaded (required)      300.0
# ...

# %%
avg_msrp_by_make = df.groupby("Make")["MSRP"].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(10,5))
avg_msrp_by_make.plot(kind='bar', color='steelblue')
plt.title("Top 10 Car Brands by Average MSRP")
plt.ylabel("Average Price")
plt.xlabel("Car Brand")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df_cleaned, x="Engine HP", y="MSRP", hue="Vehicle Size", alpha=0.6)
plt.title("Engine Horsepower vs Price by Vehicle Size")
plt.xlabel("Engine Horsepower (HP)")
plt.ylabel("MSRP")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df_cleaned, x="Vehicle Size", y="city mpg")
plt.title("City Mileage Distribution by Vehicle Size")
plt.show()

plt.figure(figsize=(8,5))
sns.boxplot(data=df_cleaned, x="Vehicle Size", y="highway MPG")
plt.title("Highway Mileage Distribution by Vehicle Size")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df_cleaned["MSRP"], bins=40, kde=True)
plt.title("Distribution of Car Prices (MSRP)")
plt.xlabel("MSRP ($)")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df_cleaned.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# %%
sns.pairplot(df[['Engine HP', 'Engine Cylinders', 'city mpg', 'highway MPG', 'MSRP']].dropna(), diag_kind='kde', corner=True)
plt.suptitle('Pair Plot of Car Features', y=1.02)
plt.show()

# %% [markdown]
# # Insights and Summary
#
# After analyzing and visualizing the This dataset captures a diverse range of cars — from economy to high-end luxury.
# Most vehicles are moderately powered, reasonably priced, and fuel-efficient.
#
# # Categorical Summary
#
# Top Makes: Ford, Chevrolet, BMW, Mercedes-Benz, Audi
#
# Top Transmission Types: Automatic, Manual, Automated Manual
#
# Driven Wheels: Mostly front wheel drive and all wheel drive
#
# Vehicle Size: Compact, Midsize, and Large dominate
#
# Vehicle Styles: Sedan, SUV, Coupe, Convertible
#
# Market Category: Luxury and Performance are most common tags
#
# # Performance vs Price
#
# Cars with higher Engine HP and Cylinders generally have higher MSRP.
#
# Strong upward trend between engine size and price.
#
# # Fuel Efficiency
#
# City MPG and Highway MPG are strongly correlated — efficient cars remain efficient across driving conditions.
#
# Inverse relation between engine power and MPG — powerful engines consume more fuel
#
# # Market & Popularity
#
# The dataset includes both mass-market and luxury brands, creating a wide MSRP range.
#
# Popularity seems brand-driven — high counts for Ford, Chevrolet, BMW, Toyota.
#
# # Vehicle Distribution
#
# Majority of vehicles are modern (2000s–2010s).
#
# Compact and midsize vehicles dominate — aligning with consumer trends.
